# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
df.columns = map(str.lower, df.columns)
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#Your code here
df.set_index('linename', inplace=True)
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
df.reset_index(inplace=True)
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
df['Num_Lines'] = df.apply(lambda x: len(x['linename']), axis=1)
df.sort_values(by='Num_Lines', ascending=False)
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    #cleaned = #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    cleaned = col_name.title()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]
df.columns
# Out:
# Index(['Linename', 'C/A', 'Unit', 'Scp', 'Station', 'Division', 'Date', 'Time',
#        'Desc', 'Entries',
#        'Exits                                                               ',
#        'Num_Lines'],
#       dtype='object')

# %%
#Checking the output, we can see the results.
df.columns
df.head()
# Out:
#   Linename   C/A  Unit       Scp Station Division        Date      Time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df.Date = pd.to_datetime(df.Date)
df.Date.dtype
df.Date.head()
# Out:
# 0   2018-08-25
# 1   2018-08-25
# 2   2018-08-25
# 3   2018-08-25
# 4   2018-08-25
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here
df['Day'] = df.Date.dt.day_name()
df.head()
# Out:
#   Linename   C/A  Unit       Scp Station Division       Date      Time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines       Day
# 0          7  Saturday
# 1          7  Saturday
# 2          7  Saturday
# 3          7  Saturday
# 4          7  Saturday

# %%
total_entries = df['Entries'].sum()
days = df.groupby('Day')['Entries'].sum()
percent = days /
# Out:
# Day
# Friday       1110224700078
# Monday       1114237052454
# Saturday     1115661545514
# Sunday       1192306179082
# Thursday     1122723988662
# Tuesday      1143313287046
# Wednesday    1123655222441
# Name: Entries, dtype: int64
# Day
# Friday       3.950837e+07
# Monday       3.943644e+07
# Saturday     4.017941e+07
# Sunday       4.245953e+07
# Thursday     3.946722e+07
# Tuesday      3.973701e+07
# Wednesday    3.984169e+07
# Name: Entries, dtype: float64

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
df.drop('Scp', axis=1)
# Out:
#        Linename    C/A  Unit        Station Division       Date      Time  \
# 0       NQR456W   A002  R051          59 ST      BMT 2018-08-25  00:00:00
# 1       NQR456W   A002  R051          59 ST      BMT 2018-08-25  04:00:00
# 2       NQR456W   A002  R051          59 ST      BMT 2018-08-25  08:00:00
# 3       NQR456W   A002  R051          59 ST      BMT 2018-08-25  12:00:00
# 4       NQR456W   A002  R051          59 ST      BMT 2018-08-25  16:00:00
# 5       NQR456W   A002  R051          59 ST      BMT 2018-08-25  20:00:00
# 6       NQR456W   A002  R051          59 ST      BMT 2018-08-26  00:00:00
# 7       NQR456W   A002  R051          59 ST      BMT 2018-08-26  04:00:00
# 8       NQR456W   A002  R051          59 ST      BMT 2018-08-26  08:00:00
# 9       NQR456W   A002  R051          59 ST      BMT 2018-08-26  12:00:00
# 10      NQR456W   A002  R051          59 ST      BMT 2018-08-26  16:00:00
# 11      NQR456W   A002  R051          59 ST      BMT 2018-08-26  20:00:00
# 12      NQR456W   A002  R051          59 ST      BMT 2018-08-27  00:00:00
# 13      NQR456W   A002  R051          59 ST      BMT 2018-08-27  04:00:00
# 14      NQR456W   A002  R051          59 ST      BMT 2018-08-27  08:00:00
# 15      NQR456W   A002  R051          59 ST      BMT 2018-08-27  12:00:00
# 16      NQR456W   A002  R051          59 ST      BMT 2018-08-27  16:00:00
# 17      NQR456W   A002  R051          59 ST      BMT 2018-08-27  20:00:00
# 18      NQR456W   A002  R051          59 ST      BMT 2018-08-28  00:00:00
# 19      NQR456W   A002  R051          59 ST      BMT 2018-08-28  04:00:00
# 20      NQR456W   A002  R051          59 ST      BMT 2018-08-28  08:00:00
# 21      NQR456W   A002  R051          59 ST      BMT 2018-08-28  12:00:00
# 22      NQR456W   A002  R051          59 ST      BMT 2018-08-28  16:00:00
# 23      NQR456W   A002  R051          59 ST      BMT 2018-08-28  20:00:00
# 24      NQR456W   A002  R051          59 ST      BMT 2018-08-29  00:00:00
# 25      NQR456W   A002  R051          59 ST      BMT 2018-08-29  04:00:00
# 26      NQR456W   A002  R051          59 ST      BMT 2018-08-29  08:00:00
# 27      NQR456W   A002  R051          59 ST      BMT 2018-08-29  12:00:00
# 28      NQR456W   A002  R051          59 ST      BMT 2018-08-29  16:00:00
# 29      NQR456W   A002  R051          59 ST      BMT 2018-08-29  20:00:00
# ...         ...    ...   ...            ...      ...        ...       ...
# 197595        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-27  01:00:00
# 197596        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-27  05:00:00
# 197597        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-27  09:00:00
# 197598        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-27  13:00:00
# 197599        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-27  17:00:00
# 197600        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-27  21:00:00
# 197601        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-28  01:00:00
# 197602        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-28  05:00:00
# 197603        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-28  09:00:00
# 197604        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-28  13:00:00
# 197605        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-28  17:00:00
# 197606        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-28  21:00:00
# 197607        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-29  01:00:00
# 197608        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-29  05:00:00
# 197609        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-29  09:00:00
# 197610        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-29  13:00:00
# 197611        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-29  17:00:00
# 197612        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-29  21:00:00
# 197613        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-30  01:00:00
# 197614        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-30  05:00:00
# 197615        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-30  09:00:00
# 197616        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-30  13:00:00
# 197617        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-30  17:00:00
# 197618        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-30  21:00:00
# 197619        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-31  01:00:00
# 197620        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-31  05:00:00
# 197621        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-31  09:00:00
# 197622        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-31  13:00:00
# 197623        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-31  17:00:00
# 197624        R  TRAM2  R469  RIT-ROOSEVELT      RIT 2018-08-31  21:00:00
#
#            Desc  Entries  \
# 0       REGULAR  6736067
# 1       REGULAR  6736087
# 2       REGULAR  6736105
# 3       REGULAR  6736180
# 4       REGULAR  6736349
# 5       REGULAR  6736562
# 6       REGULAR  6736683
# 7       REGULAR  6736696
# 8       REGULAR  6736705
# 9       REGULAR  6736746
# 10      REGULAR  6736873
# 11      REGULAR  6737067
# 12      REGULAR  6737136
# 13      REGULAR  6737146
# 14      REGULAR  6737169
# 15      REGULAR  6737301
# 16      REGULAR  6737553
# 17      REGULAR  6738257
# 18      REGULAR  6738430
# 19      REGULAR  6738442
# 20      REGULAR  6738474
# 21      REGULAR  6738621
# 22      REGULAR  6738886
# 23      REGULAR  6739630
# 24      REGULAR  6739804
# 25      REGULAR  6739812
# 26      REGULAR  6739847
# 27      REGULAR  6739986
# 28      REGULAR  6740257
# 29      REGULAR  6740888
# ...         ...      ...
# 197595  REGULAR     5554
# 197596  REGULAR     5554
# 197597  REGULAR     5554
# 197598  REGULAR     5554
# 197599  REGULAR     5554
# 197600  REGULAR     5554
# 197601  REGULAR     5554
# 197602  REGULAR     5554
# 197603  REGULAR     5554
# 197604  REGULAR     5554
# 197605  REGULAR     5554
# 197606  REGULAR     5554
# 197607  REGULAR     5554
# 197608  REGULAR     5554
# 197609  REGULAR     5554
# 197610  REGULAR     5554
# 197611  REGULAR     5554
# 197612  REGULAR     5554
# 197613  REGULAR     5554
# 197614  REGULAR     5554
# 197615  REGULAR     5554
# 197616  REGULAR     5554
# 197617  REGULAR     5554
# 197618  REGULAR     5554
# 197619  REGULAR     5554
# 197620  REGULAR     5554
# 197621  REGULAR     5554
# 197622  REGULAR     5554
# 197623  REGULAR     5554
# 197624  REGULAR     5554
#
#         Exits                                                                 \
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# 5                                                 2283425
# 6                                                 2283460
# 7                                                 2283461
# 8                                                 2283483
# 9                                                 2283524
# 10                                                2283587
# 11                                                2283631
# 12                                                2283656
# 13                                                2283658
# 14                                                2283736
# 15                                                2283965
# 16                                                2284025
# 17                                                2284091
# 18                                                2284121
# 19                                                2284126
# 20                                                2284216
# 21                                                2284402
# 22                                                2284425
# 23                                                2284478
# 24                                                2284508
# 25                                                2284512
# 26                                                2284600
# 27                                                2284838
# 28                                                2284896
# 29                                                2284941
# ...                                                   ...
# 197595                                                348
# 197596                                                348
# 197597                                                348
# 197598                                                348
# 197599                                                348
# 197600                                                348
# 197601                                                348
# 197602                                                348
# 197603                                                348
# 197604                                                348
# 197605                                                348
# 197606                                                348
# 197607                                                348
# 197608                                                348
# 197609                                                348
# 197610                                                348
# 197611                                                348
# 197612                                                348
# 197613                                                348
# 197614                                                348
# 197615                                                348
# 197616                                                348
# 197617                                                348
# 197618                                                348
# 197619                                                348
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
#         Num_Lines        Day
# 0               7   Saturday
# 1               7   Saturday
# 2               7   Saturday
# 3               7   Saturday
# 4               7   Saturday
# 5               7   Saturday
# 6               7     Sunday
# 7               7     Sunday
# 8               7     Sunday
# 9               7     Sunday
# 10              7     Sunday
# 11              7     Sunday
# 12              7     Monday
# 13              7     Monday
# 14              7     Monday
# 15              7     Monday
# 16              7     Monday
# 17              7     Monday
# 18              7    Tuesday
# 19              7    Tuesday
# 20              7    Tuesday
# 21              7    Tuesday
# 22              7    Tuesday
# 23              7    Tuesday
# 24              7  Wednesday
# 25              7  Wednesday
# 26              7  Wednesday
# 27              7  Wednesday
# 28              7  Wednesday
# 29              7  Wednesday
# ...           ...        ...
# 197595          1     Monday
# 197596          1     Monday
# 197597          1     Monday
# 197598          1     Monday
# 197599          1     Monday
# 197600          1     Monday
# 197601          1    Tuesday
# 197602          1    Tuesday
# 197603          1    Tuesday
# 197604          1    Tuesday
# 197605          1    Tuesday
# 197606          1    Tuesday
# 197607          1  Wednesday
# 197608          1  Wednesday
# 197609          1  Wednesday
# 197610          1  Wednesday
# 197611          1  Wednesday
# 197612          1  Wednesday
# 197613          1   Thursday
# 197614          1   Thursday
# 197615          1   Thursday
# 197616          1   Thursday
# 197617          1   Thursday
# 197618          1   Thursday
# 197619          1     Friday
# 197620          1     Friday
# 197621          1     Friday
# 197622          1     Friday
# 197623          1     Friday
# 197624          1     Friday
#
# [197625 rows x 12 columns]
